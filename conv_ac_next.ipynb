# %%
import os

import cv2
import numpy as np
import matplotlib.pyplot as plt
from IPython.display import clear_output
# %matplotlib inline

import keras
from keras.layers import Input, Dense, Conv2D, MaxPooling2D, UpSampling2D
from keras.models import Model
from keras import backend as K
from keras.preprocessing.image import ImageDataGenerator

from sklearn.model_selection import train_test_split

from simple_movement import DataGen
# Out:
# Using TensorFlow backend.

# %%
BASE_PATH = 'C:\\Users\\ttanj\\UoB\\WS18\\DBM\\data\data_simple_movement'
HEIGHT = 100
WIDTH = 100
NUM_CHANNEL = 2
RGB = 0

# %%
input_img = Input(shape=(HEIGHT, WIDTH, NUM_CHANNEL))

x = Conv2D(16, (3, 3), activation='relu', padding='same')(input_img)
x = MaxPooling2D((2, 2), padding='same')(x)
x = Conv2D(8, (3, 3), activation='relu', padding='same')(x)
x = MaxPooling2D((2, 2), padding='same')(x)
x = Conv2D(8, (3, 3), activation='relu', padding='same')(x)
encoded = MaxPooling2D((2, 2), padding='same')(x)

x = Conv2D(8, (3, 3), activation='relu', padding='same')(encoded)
x = UpSampling2D((2, 2))(x)
x = Conv2D(8, (3, 3), activation='relu', padding='same')(x)
x = UpSampling2D((2, 2))(x)
x = Conv2D(16, (3, 3), activation='relu')(x)
x = UpSampling2D((2, 2))(x)
decoded = Conv2D(1, (3, 3), activation='sigmoid', padding='same')(x)

autoencoder = Model(input_img, decoded)
autoencoder.compile(optimizer='adam', loss='binary_crossentropy')
autoencoder.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         (None, 100, 100, 2)       0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 100, 100, 16)      304
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 50, 50, 16)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 50, 50, 8)         1160
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 25, 25, 8)         0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 25, 25, 8)         584
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 13, 13, 8)         0
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 13, 13, 8)         584
# _________________________________________________________________
# up_sampling2d_1 (UpSampling2 (None, 26, 26, 8)         0
# _________________________________________________________________
# conv2d_5 (Conv2D)            (None, 26, 26, 8)         584
# _________________________________________________________________
# up_sampling2d_2 (UpSampling2 (None, 52, 52, 8)         0
# _________________________________________________________________
# conv2d_6 (Conv2D)            (None, 50, 50, 16)        1168
# _________________________________________________________________
# up_sampling2d_3 (UpSampling2 (None, 100, 100, 16)      0
# _________________________________________________________________
# conv2d_7 (Conv2D)            (None, 100, 100, 1)       145
# =================================================================
# Total params: 4,529
# Trainable params: 4,529
# Non-trainable params: 0
# _________________________________________________________________

# %%
dgen = DataGen(HEIGHT, WIDTH, NUM_CHANNEL)
x, y = dgen.prepare_data()

x = x / 255.
y = y / 255.

x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.1, shuffle=True)

autoencoder.fit(x_train, y_train,
                epochs=100,
                batch_size=10,
                shuffle=True,
                validation_data=(x_test, y_test))
# Out:
# Train on 194 samples, validate on 22 samples
# Epoch 1/100
# 194/194 [==============================] - 6s 33ms/step - loss: 0.3399 - val_loss: 0.2162
# Epoch 2/100
# 194/194 [==============================] - 6s 31ms/step - loss: 0.1821 - val_loss: 0.1709
# Epoch 3/100
# 194/194 [==============================] - 6s 32ms/step - loss: 0.1656 - val_loss: 0.1559
# Epoch 4/100
# 194/194 [==============================] - 6s 31ms/step - loss: 0.1445 - val_loss: 0.1290
# Epoch 5/100
# 194/194 [==============================] - 6s 30ms/step - loss: 0.1142 - val_loss: 0.0965
# Epoch 6/100
# 194/194 [==============================] - 5s 28ms/step - loss: 0.0875 - val_loss: 0.0776
# Epoch 7/100
# 194/194 [==============================] - 5s 28ms/step - loss: 0.0717 - val_loss: 0.0639
# Epoch 8/100
# 194/194 [==============================] - 5s 28ms/step - loss: 0.0574 - val_loss: 0.0494
# Epoch 9/100
# 194/194 [==============================] - 5s 28ms/step - loss: 0.0446 - val_loss: 0.0385
# Epoch 10/100
# 194/194 [==============================] - 6s 31ms/step - loss: 0.0353 - val_loss: 0.0310
# Epoch 11/100
# 194/194 [==============================] - 6s 33ms/step - loss: 0.0293 - val_loss: 0.0277
# Epoch 12/100
# 194/194 [==============================] - 6s 33ms/step - loss: 0.0268 - val_loss: 0.0248
# Epoch 13/100
# 194/194 [==============================] - 6s 34ms/step - loss: 0.0243 - val_loss: 0.0239
# Epoch 14/100
# 194/194 [==============================] - 7s 36ms/step - loss: 0.0255 - val_loss: 0.0223
# Epoch 15/100
# 194/194 [==============================] - 7s 35ms/step - loss: 0.0225 - val_loss: 0.0217
# Epoch 16/100
# 194/194 [==============================] - 6s 32ms/step - loss: 0.0218 - val_loss: 0.0211
# Epoch 17/100
# 194/194 [==============================] - 6s 33ms/step - loss: 0.0214 - val_loss: 0.0210
# Epoch 18/100
# 194/194 [==============================] - 7s 34ms/step - loss: 0.0212 - val_loss: 0.0206
# Epoch 19/100
# 194/194 [==============================] - 6s 32ms/step - loss: 0.0209 - val_loss: 0.0210
# Epoch 20/100
# 194/194 [==============================] - 7s 34ms/step - loss: 0.0208 - val_loss: 0.0203
# Epoch 21/100
# 194/194 [==============================] - 7s 35ms/step - loss: 0.0206 - val_loss: 0.0207
# Epoch 22/100
# 194/194 [==============================] - 7s 34ms/step - loss: 0.0206 - val_loss: 0.0201
# Epoch 23/100
# 194/194 [==============================] - 7s 38ms/step - loss: 0.0203 - val_loss: 0.0201
# Epoch 24/100
# 194/194 [==============================] - 10s 50ms/step - loss: 0.0203 - val_loss: 0.0199
# Epoch 25/100
# 194/194 [==============================] - 11s 57ms/step - loss: 0.0203 - val_loss: 0.0201
# Epoch 26/100
# 194/194 [==============================] - 11s 56ms/step - loss: 0.0201 - val_loss: 0.0201
# Epoch 27/100
# 194/194 [==============================] - 11s 55ms/step - loss: 0.0201 - val_loss: 0.0197
# Epoch 28/100
# 194/194 [==============================] - 11s 59ms/step - loss: 0.0200 - val_loss: 0.0197
# Epoch 29/100
# 194/194 [==============================] - 12s 61ms/step - loss: 0.0199 - val_loss: 0.0197
# Epoch 30/100
# 194/194 [==============================] - 12s 63ms/step - loss: 0.0199 - val_loss: 0.0197
# Epoch 31/100
# 194/194 [==============================] - 13s 67ms/step - loss: 0.0198 - val_loss: 0.0195
# Epoch 32/100
# 194/194 [==============================] - 11s 57ms/step - loss: 0.0197 - val_loss: 0.0196
# Epoch 33/100
# 194/194 [==============================] - 12s 63ms/step - loss: 0.0197 - val_loss: 0.0194
# Epoch 34/100
# 194/194 [==============================] - 11s 58ms/step - loss: 0.0197 - val_loss: 0.0193
# Epoch 35/100
# 194/194 [==============================] - 12s 63ms/step - loss: 0.0196 - val_loss: 0.0193
# Epoch 36/100
# 194/194 [==============================] - 11s 58ms/step - loss: 0.0197 - val_loss: 0.0194
# Epoch 37/100
# 194/194 [==============================] - 11s 55ms/step - loss: 0.0196 - val_loss: 0.0194
# Epoch 38/100
# 194/194 [==============================] - 11s 54ms/step - loss: 0.0195 - val_loss: 0.0192
# Epoch 39/100
# 194/194 [==============================] - 11s 55ms/step - loss: 0.0195 - val_loss: 0.0192
# Epoch 40/100
# 194/194 [==============================] - 11s 56ms/step - loss: 0.0195 - val_loss: 0.0191
# Epoch 41/100
# 194/194 [==============================] - 11s 58ms/step - loss: 0.0196 - val_loss: 0.0193
# Epoch 42/100
# 194/194 [==============================] - 12s 64ms/step - loss: 0.0197 - val_loss: 0.0192
# Epoch 43/100
# 194/194 [==============================] - 11s 56ms/step - loss: 0.0196 - val_loss: 0.0191
# Epoch 44/100
# 194/194 [==============================] - 12s 60ms/step - loss: 0.0194 - val_loss: 0.0192
# Epoch 45/100
# 194/194 [==============================] - 13s 67ms/step - loss: 0.0194 - val_loss: 0.0192
# Epoch 46/100
# 194/194 [==============================] - 13s 67ms/step - loss: 0.0192 - val_loss: 0.0190
# Epoch 47/100
# 194/194 [==============================] - 14s 70ms/step - loss: 0.0192 - val_loss: 0.0192
# Epoch 48/100
# 194/194 [==============================] - 12s 61ms/step - loss: 0.0194 - val_loss: 0.0190
# Epoch 49/100
# 194/194 [==============================] - 12s 63ms/step - loss: 0.0192 - val_loss: 0.0189
# Epoch 50/100
# 194/194 [==============================] - 13s 66ms/step - loss: 0.0191 - val_loss: 0.0189
# Epoch 51/100
# 194/194 [==============================] - 12s 64ms/step - loss: 0.0192 - val_loss: 0.0190
# Epoch 52/100
# 194/194 [==============================] - 13s 67ms/step - loss: 0.0193 - val_loss: 0.0189
# Epoch 53/100
# 194/194 [==============================] - 13s 66ms/step - loss: 0.0192 - val_loss: 0.0189
# Epoch 54/100
# 194/194 [==============================] - 13s 67ms/step - loss: 0.0190 - val_loss: 0.0187
# Epoch 55/100
# 194/194 [==============================] - 13s 65ms/step - loss: 0.0190 - val_loss: 0.0190
# Epoch 56/100
# 194/194 [==============================] - 12s 61ms/step - loss: 0.0191 - val_loss: 0.0187
# Epoch 57/100
# 194/194 [==============================] - 13s 65ms/step - loss: 0.0190 - val_loss: 0.0188
# Epoch 58/100
# 194/194 [==============================] - 14s 72ms/step - loss: 0.0191 - val_loss: 0.0189
# Epoch 59/100
# 194/194 [==============================] - 12s 63ms/step - loss: 0.0190 - val_loss: 0.0188
# Epoch 60/100
# 194/194 [==============================] - 12s 61ms/step - loss: 0.0189 - val_loss: 0.0186
# Epoch 61/100
# 194/194 [==============================] - 14s 71ms/step - loss: 0.0189 - val_loss: 0.0187
# Epoch 62/100
# 194/194 [==============================] - 12s 62ms/step - loss: 0.0188 - val_loss: 0.0186
# Epoch 63/100
# 194/194 [==============================] - 12s 64ms/step - loss: 0.0194 - val_loss: 0.0189
# Epoch 64/100
# 194/194 [==============================] - 14s 74ms/step - loss: 0.0189 - val_loss: 0.0186
# Epoch 65/100
# 194/194 [==============================] - 12s 64ms/step - loss: 0.0188 - val_loss: 0.0185
# Epoch 66/100
# 194/194 [==============================] - 13s 69ms/step - loss: 0.0190 - val_loss: 0.0188
# Epoch 67/100
# 194/194 [==============================] - 12s 64ms/step - loss: 0.0189 - val_loss: 0.0185
# Epoch 68/100
# 194/194 [==============================] - 12s 63ms/step - loss: 0.0188 - val_loss: 0.0186
# Epoch 69/100
# 194/194 [==============================] - 12s 59ms/step - loss: 0.0188 - val_loss: 0.0185
# Epoch 70/100
# 194/194 [==============================] - 12s 61ms/step - loss: 0.0189 - val_loss: 0.0185
# Epoch 71/100
# 194/194 [==============================] - 12s 60ms/step - loss: 0.0190 - val_loss: 0.0187
# Epoch 72/100
# 194/194 [==============================] - 12s 60ms/step - loss: 0.0188 - val_loss: 0.0184
# Epoch 73/100
# 194/194 [==============================] - 12s 62ms/step - loss: 0.0187 - val_loss: 0.0185
# Epoch 74/100
# 194/194 [==============================] - 13s 67ms/step - loss: 0.0186 - val_loss: 0.0185
# Epoch 75/100
# 194/194 [==============================] - 13s 69ms/step - loss: 0.0186 - val_loss: 0.0196
# Epoch 76/100
# 194/194 [==============================] - 13s 66ms/step - loss: 0.0188 - val_loss: 0.0185
# Epoch 77/100
# 194/194 [==============================] - 13s 65ms/step - loss: 0.0188 - val_loss: 0.0185
# Epoch 78/100
# 194/194 [==============================] - 12s 64ms/step - loss: 0.0186 - val_loss: 0.0185
# Epoch 79/100
# 194/194 [==============================] - 13s 69ms/step - loss: 0.0187 - val_loss: 0.0185
# Epoch 80/100
# 194/194 [==============================] - 13s 68ms/step - loss: 0.0188 - val_loss: 0.0186
# Epoch 81/100
# 194/194 [==============================] - 13s 67ms/step - loss: 0.0188 - val_loss: 0.0185
# Epoch 82/100
# 194/194 [==============================] - 14s 72ms/step - loss: 0.0187 - val_loss: 0.0194
# Epoch 83/100
# 194/194 [==============================] - 11s 57ms/step - loss: 0.0188 - val_loss: 0.0185
# Epoch 84/100
# 194/194 [==============================] - 11s 57ms/step - loss: 0.0186 - val_loss: 0.0183
# Epoch 85/100
# 194/194 [==============================] - 11s 58ms/step - loss: 0.0186 - val_loss: 0.0182
# Epoch 86/100
# 194/194 [==============================] - 11s 56ms/step - loss: 0.0184 - val_loss: 0.0187
# Epoch 87/100
# 194/194 [==============================] - 11s 58ms/step - loss: 0.0185 - val_loss: 0.0182
# Epoch 88/100
# 194/194 [==============================] - 13s 68ms/step - loss: 0.0184 - val_loss: 0.0183
# Epoch 89/100
# 194/194 [==============================] - 12s 63ms/step - loss: 0.0186 - val_loss: 0.0184
# Epoch 90/100
# 194/194 [==============================] - 14s 72ms/step - loss: 0.0185 - val_loss: 0.0184
# Epoch 91/100
# 194/194 [==============================] - 13s 68ms/step - loss: 0.0185 - val_loss: 0.0182
# Epoch 92/100
# 194/194 [==============================] - 13s 69ms/step - loss: 0.0185 - val_loss: 0.0182
# Epoch 93/100
# 194/194 [==============================] - 13s 67ms/step - loss: 0.0184 - val_loss: 0.0183
# Epoch 94/100
# 194/194 [==============================] - 12s 61ms/step - loss: 0.0184 - val_loss: 0.0182
# Epoch 95/100
# 194/194 [==============================] - 12s 63ms/step - loss: 0.0183 - val_loss: 0.0182
# Epoch 96/100
# 194/194 [==============================] - 12s 63ms/step - loss: 0.0183 - val_loss: 0.0182
# Epoch 97/100
# 194/194 [==============================] - 12s 63ms/step - loss: 0.0183 - val_loss: 0.0183
# Epoch 98/100
# 194/194 [==============================] - 12s 61ms/step - loss: 0.0184 - val_loss: 0.0187
# Epoch 99/100
# 194/194 [==============================] - 11s 58ms/step - loss: 0.0184 - val_loss: 0.0182
# Epoch 100/100
# 194/194 [==============================] - 11s 58ms/step - loss: 0.0184 - val_loss: 0.0184

# %%
decoded_imgs = autoencoder.predict(x_test)

# %%
idx = 5

plt.figure(figsize=(10, 3))

# display original
ax = plt.subplot(1, 4, 1)
plt.imshow(x_test[idx][:, :, 0].reshape(HEIGHT, WIDTH))
plt.gray()
ax.get_xaxis().set_visible(False)
ax.get_yaxis().set_visible(False)

ax = plt.subplot(1, 4, 2)
plt.imshow(x_test[idx][:, :, 1].reshape(HEIGHT, WIDTH))
plt.gray()
ax.get_xaxis().set_visible(False)
ax.get_yaxis().set_visible(False)

# display reconstruction
ax = plt.subplot(1, 4, 3)
plt.imshow(decoded_imgs[idx][:, :, 0].reshape(HEIGHT, WIDTH))
plt.gray()
ax.get_xaxis().set_visible(False)
ax.get_yaxis().set_visible(False)

ax = plt.subplot(1, 4, 4)
plt.imshow(y_test[idx][:, :, 0].reshape(HEIGHT, WIDTH))
plt.gray()
ax.get_xaxis().set_visible(False)
ax.get_yaxis().set_visible(False)

plt.show()
